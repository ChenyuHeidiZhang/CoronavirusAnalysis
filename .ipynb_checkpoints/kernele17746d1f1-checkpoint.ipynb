# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import pandas as pd
# directory = '/kaggle/input/novel-corona-virus-2019-dataset/'
directory = ''
data_311 = '03-11-2020.csv'
data_kag = 'novel-corona-virus-2019-dataset/covid_19_data.csv'
main_set = pd.read_csv(directory + data_311)
main_set.head()
# Out:
#   Province/State Country/Region          Last Update  Confirmed  Deaths  \
# 0          Hubei          China  2020-03-11T10:53:02      67773    3046
# 1            NaN          Italy  2020-03-11T21:33:02      12462     827
# 2            NaN           Iran  2020-03-11T18:52:03       9000     354
# 3            NaN   Korea, South  2020-03-11T21:13:18       7755      60
# 4         France         France  2020-03-11T22:53:03       2281      48
#
#    Recovered  Latitude  Longitude
# 0      49134   30.9756   112.2707
# 1       1045   43.0000    12.0000
# 2       2959   32.0000    53.0000
# 3        288   36.0000   128.0000
# 4         12   46.2276     2.2137

# %%
US = main_set[main_set['Country/Region'] == 'US']
US.head()
# Out:
#       Province/State Country/Region          Last Update  Confirmed  Deaths  \
# 27        Washington             US  2020-03-11T22:33:03        366      29
# 36          New York             US  2020-03-11T22:53:03        220       0
# 39        California             US  2020-03-11T23:53:03        177       3
# 51     Massachusetts             US  2020-03-11T22:53:03         95       0
# 72  Diamond Princess             US  2020-03-10T02:33:04         46       0
#
#     Recovered  Latitude  Longitude
# 27          1   47.4009  -121.4905
# 36          0   42.1657   -74.9481
# 39          2   36.1162  -119.6816
# 51          1   42.2302   -71.5301
# 72          0   35.4437   139.6380

# %%
population = {'China': 1408526449,
              'Korea': 51269185,
              'Italy': 60461826,
              'USA':   331002651
             }

# %% [markdown]
# compare the outbreak trend in different countries

# %% [markdown]
# China vs. Korea

# %%
import matplotlib.pyplot as plt

# %%
def clean_time_data(data):
    data = data.drop('Lat', axis=1).drop("Long", axis=1)
    data = data.dropna(axis=1)
    data = data.groupby('Country/Region').sum()
    return data

# %%
data = pd.read_csv(directory + 'novel-corona-virus-2019-dataset/time_series_covid_19_confirmed.csv')
data = clean_time_data(data)

# %%
china = data.loc['Mainland China']
plt.plot(china)

# %%
korea = data.loc['South Korea']
plt.plot(korea)

# %%
data_death = pd.read_csv(directory + 'novel-corona-virus-2019-dataset/time_series_covid_19_deaths.csv')
data_recovered = pd.read_csv(directory + 'novel-corona-virus-2019-dataset/time_series_covid_19_recovered.csv')

data_death = clean_time_data(data_death)
data_recovered = clean_time_data(data_recovered)

# %%
china_death = data_death.loc['Mainland China']
china_recovered = data_recovered.loc['Mainland China']
plt.plot(china, label='confirmed')
plt.plot(china_death, label='death')
plt.plot(china_recovered, label='recovered')
plt.legend()

# %%
china_active_proportion = (china - china_death - china_recovered)/population['China'] * 10000
plt.plot(china_active_proportion)

# %%
korea_death = data_death.loc['South Korea']
korea_recovered = data_recovered.loc['South Korea']
plt.plot(korea, label='confirmed')
plt.plot(korea_death, label='death')
plt.plot(korea_recovered, label='recovered')
plt.legend()

# %%
korea_active_proportion = (korea - korea_death - korea_recovered) / population['Korea'] * 10000
plt.plot(korea_active_proportion)

# %%
usa = data.loc['US']
plt.plot(USA)

# %%
usa_death = data_death.loc['US']
usa_recovered = data_recovered.loc['US']
plt.plot(usa, label='confirmed')
plt.plot(usa_death, label='death')
plt.plot(usa_recovered, label='recovered')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-a03ab988c410> in <module>
#       1 usa_death = data_death.loc['US']
#       2 usa_recovered = data_recovered.loc['US']
# ----> 3 plt.plot(usa, label='confirmed')
#       4 plt.plot(usa_death, label='death')
#       5 plt.plot(usa_recovered, label='recovered')
#
# NameError: name 'usa' is not defined
